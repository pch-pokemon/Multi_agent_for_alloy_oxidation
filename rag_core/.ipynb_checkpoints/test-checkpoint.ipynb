# %% [markdown]
# # 导入工具使用

# %%
from rag_core import print_answer_tool

# %%
result = print_answer_tool.invoke({
    "query": "what is the Co-based alloy?",
    "debug": True,
    "render_markdown": True
})
print(result)
# Out:
# Co-based superalloys are high-temperature materials primarily composed of cobalt, designed for applications like turbine engines and gas turbines due to their higher melting point, superior hot corrosion resistance, and high-temperature mechanical properties compared to Ni-based superalloys. They are categorized into two main types:
# 1. **Traditional alloys** (e.g., Haynes188, Alloy 255, Co-101, Stellite-21): Strengthened by solid-solution hardening and carbide precipitation, offering excellent corrosion resistance but inferior mechanical properties to γ'-strengthened Ni-alloys [1].
# 2. **γ'-strengthened alloys**: Feature a stable Co₃(Al,W) intermetallic phase with an L1₂ structure (γ'-phase) precipitated within a γ-Co matrix, providing high-temperature strength comparable to Ni-based superalloys [2].
#
# Commercial examples include Co-101 (high carbon) and Stellite-21 (low carbon), both exhibiting dendritic microstructures (Table 1) [3].
# **Table1.** Nominal and actual \(determined by EDX\) compositions of alloys Co-101 and Stellite-21. [🔗](https://github.com/pch-pokemon/knowledge_base/raw/main/35/Table1.png)
# **Reference:**
# [1] Influence of small amounts of Si and Cr on the high-temperature oxidation behavior of novel cobalt base superalloys, DOI: https://doi.org/10.1016/j.corsci.2021.109388
# [2] Corrosion properties of novel γ'-strengthened Co-base superalloys, DOI: https://doi.org/10.1016/j.corsci.2012.09.025
# [3] The Effect of Heat Treatment on the Oxidation Resistance of Cobalt-Based Superalloys, DOI: https://doi.org/10.3390/met10020248
# [DBG] ------- DEBUG REPORT -------
# [DBG][retrieve_base] {"query": "what is the Co-based alloy?", "base_docs": 5}
# [DBG][base_doc] {"idx": 1, "source": "D:/knowledge_base/Data/19.json", "meta_keys": ["source", "section_number", "section_title", "hierarchy_level", "chunk_number", "total_chunks", "ref_Fig/Table", "relevance_score"]}
# [DBG][refs_in_doc] {"idx": 1, "source": "D:/knowledge_base/Data/19.json", "figures": [], "tables": []}
# [DBG][base_doc] {"idx": 2, "source": "D:/knowledge_base/Data/6.json", "meta_keys": ["source", "section_number", "section_title", "hierarchy_level", "chunk_number", "total_chunks", "ref_Fig/Table", "relevance_score"]}
# [DBG][refs_in_doc] {"idx": 2, "source": "D:/knowledge_base/Data/6.json", "figures": [], "tables": []}
# [DBG][base_doc] {"idx": 3, "source": "D:/knowledge_base/Data/41.json", "meta_keys": ["source", "section_number", "section_title", "hierarchy_level", "chunk_number", "total_chunks", "ref_Fig/Table", "relevance_score"]}
# [DBG][refs_in_doc] {"idx": 3, "source": "D:/knowledge_base/Data/41.json", "figures": [], "tables": []}
# [DBG][base_doc] {"idx": 4, "source": "D:/knowledge_base/Data/23.json", "meta_keys": ["source", "section_number", "section_title", "hierarchy_level", "chunk_number", "total_chunks", "ref_Fig/Table", "relevance_score"]}
# [DBG][refs_in_doc] {"idx": 4, "source": "D:/knowledge_base/Data/23.json", "figures": [], "tables": []}
# [DBG][base_doc] {"idx": 5, "source": "D:/knowledge_base/Data/35.json", "meta_keys": ["source", "section_number", "section_title", "hierarchy_level", "chunk_number", "total_chunks", "ref_Fig/Table", "relevance_score"]}
# [DBG][refs_in_doc] {"idx": 5, "source": "D:/knowledge_base/Data/35.json", "figures": [], "tables": ["Table 1"]}
# [DBG][inject_table] {"idx": 5, "source": "D:/knowledge_base/Data/35.json", "label": "Table 1", "raw_no": "Table 1", "cap": "Table 1 Nominal and actual (determined by EDX) compositions of alloys Co-101 and …", "url": "https://github.com/pch-pokemon/knowledge_base/raw/main/35/Table1.png"}
# [DBG][inject_whitelist] {"allowed": ["D:/knowledge_base/Data/19.json", "D:/knowledge_base/Data/6.json", "D:/knowledge_base/Data/41.json", "D:/knowledge_base/Data/23.json", "D:/knowledge_base/Data/35.json"]}
# [DBG][retrieve_done] {"enhanced_docs": 7}
# [DBG] Available charts in context (sorted by number):
#   - (table) src=D:/knowledge_base/Data/35.json raw=Table 1 cap=Nominal and actual (determined by EDX) compositions of alloys Co-101 and Stellit … url=https://github.com/pch-pokemon/knowledge_base/raw/main/35/Table1.png
# [DBG] LLM <CHARTS> used (ordered):
#   tables: [{"source": "D:/knowledge_base/Data/35.json", "label": "Table 1"}]
#   figures: []
# [DBG] LLM <SOURCES> used (after filtering, ordered): ["D:/knowledge_base/Data/6.json", "D:/knowledge_base/Data/41.json", "D:/knowledge_base/Data/35.json"]
# [DBG] All cited sources are present in context.
# [DBG] Matched charts (as printed):
#   Table1 <= (src=D:/knowledge_base/Data/35.json, raw=Table 1) cap=Nominal and actual (determined by EDX) compositions of alloys Co-101 and Stellit …
# [DBG] ------- END DEBUG -------

# %% [markdown]
# # 智能体测试

# %%
from rag_core import rag_alloy_chat
rag_alloy_chat("Wat's the γ/γ' phase? ")
# Out:
# Update from node agent:
#
#
# ================================== Ai Message ==================================
# Name: RAG_agent
# Tool Calls:
#   print_answer_tool (call_-8356543902673163721)
#  Call ID: call_-8356543902673163721
#   Args:
#     query: What is the γ/γ' phase in superalloys?
#
#
# Update from node tools:
#
#
# ================================= Tool Message =================================
# Name: print_answer_tool
#
# The γ/γ' phase in superalloys refers to a two-phase coherent microstructure consisting of a γ matrix phase and γ' precipitates. The γ phase is a solid solution matrix (γ-Co SS in Co-based superalloys), while the γ' phase is an ordered intermetallic compound with L1₂ structure (γ'-Co₃(Al, W) in Co-based superalloys, similar to Ni₃Al in Ni-based superalloys) [1]. The γ' precipitates typically exhibit a cuboidal morphology with sizes ranging from 100-300 nm, as shown in Fig. 1 [2]. This γ/γ' microstructure is crucial for the high-temperature mechanical properties of superalloys, with Co-based variants having melting points 50-100 K higher than Ni-based superalloys [1].
# Fig.1: Back-scattered SEM images of the aged 0Me (a), 2Mo (b), 2Hf (c) and 2Nb (e) alloys. (d) and (f) are higher magnification images of the 2Hf and 2Nb alloys, respectively.，url：https://github.com/pch-pokemon/knowledge_base/raw/main/25/Fig.1.png
# Reference:
# [1] Coarsening behavior of γ' precipitates and compression deformation mechanism of a novel Co–V–Ta–Ti superalloy, DOI: https://doi.org/10.1016/j.msea.2020.139455
# [2] High-temperature oxidation behaviour of novel Co-Al-W-Ta-B-(Mo, Hf, Nb) alloys with a coherent γ/γ'–dominant microstructure, DOI: https://doi.org/10.1016/j.pnsc.2016.11.005
