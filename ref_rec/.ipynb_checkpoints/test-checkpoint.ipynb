# %% [markdown]
# # 工具导入

# %%
from ref_REC import print_ref_answer_tool
# Out:
# ✅ Ref 索引加载成功/Ref Index loading successful!

# %%
result = print_ref_answer_tool.invoke({
    "query": "could you recommend any literature on the role of γ' in the oxidation of Ni-based alloys?",
    "debug": True
})
print(result)
# Out:
# Based on current research findings, Here is about literature investigating the role of the γ' phase in the oxidation behavior of Ni-based superalloys, focusing on its influence on oxide scale formation, protective layer development, and diffusion processes.
#
# 1) Title: Early stages of high-temperature oxidation of Ni- and Co-base model superalloys: A comparative study using rapid thermal annealing and advanced electron microscopy
#    Key finding: This study directly demonstrates the individual role of the γ and γ' phases during initial oxidation at 900 °C. Using model Ni-base and Co-base superalloys with identical alloying additions, it shows that differences in Al₂O₃ formation correlate strongly with the partitioning behavior of elements and the type of defects introduced by the γ' phase.
#    DOI: https://doi.org/10.1016/j.corsci.2021.109744
#
# 2) Title: The effect of systematic variation of Ni:Co ratio on the oxidation behaviour of γ-γ′ Ni-Co-Al-Ti-Cr alloys
# ...

# %% [markdown]
# # 智能体能力测试

# %%
from ref_REC import ref_alloy_chat
ref_alloy_chat("can you recommend some Ti role in oxidation of Co-based alloy ?")
# Out:
# Update from node agent:
#
#
# ================================== Ai Message ==================================
# Name: REF_agent
# Tool Calls:
#   print_ref_answer_tool (call_-8377584363376375526)
#  Call ID: call_-8377584363376375526
#   Args:
#     query: Ti role in oxidation of Co-based alloy
#
#
# Update from node tools:
#
#
# ================================= Tool Message =================================
# Name: print_ref_answer_tool
#
# Here is about the role of titanium (Ti) in the oxidation behavior of cobalt-based superalloys, based on the provided papers.
#
# 1) Title: Role of Ti on Phase Evolution, Oxidation and Nitridation of Co–30Ni–10Al–8Cr–5Mo–2Nb–(0, 2 & 4) Ti Cobalt Base Superalloys at Elevated Temperature
#    Key finding: Ti addition enhances γ'-solvus temperature and alters γ'-precipitate shape. However, 4 at.% Ti promotes the formation of topologically-close-packed (TCP) phases rich in Co, Cr, and Mo, which can negatively impact oxidation resistance.
# ...
